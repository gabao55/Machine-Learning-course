# %% [markdown]
# # Extracting a data subset from a data set

# %%
import pandas as pd

# %%
data = pd.read_csv(r'../datasets/customer-churn-model/Customer Churn Model.txt')

# %%
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# 0       244.7           91         11.01       10.0           3         2.70
# 1       254.4          103         11.45       13.7           3         3.70
# 2       162.6          104          7.32       12.2           5         3.29
# 3       196.9           89          8.86        6.6           7         1.78
# 4       186.9          121          8.41       10.1           3         2.73
#
#    CustServ Calls  Churn?
# 0               1  False.
# 1               1  False.
# 2               0  False.
# 3               2  False.
# 4               3  False.
#
# [5 rows x 21 columns]

# %% [markdown]
# Selecting a serie from the dataset (type = Series):

# %%
account_length = data['Account Length']
account_length.head()
# Out:
# 0    128
# 1    107
# 2    137
# 3     84
# 4     75
# Name: Account Length, dtype: int64

# %%
type(account_length)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Selecting multiple series from the dataset (typer = DataFrame):

# %%
subset = data[['Account Length', 'Phone', 'Eve Charge', 'Day Calls']]
subset.head()
# Out:
#    Account Length     Phone  Eve Charge  Day Calls
# 0             128  382-4657       16.78        110
# 1             107  371-7191       16.62        123
# 2             137  358-1921       10.30        114
# 3              84  375-9999        5.26         71
# 4              75  330-6626       12.61        113

# %%
type(subset)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# An easier way to get a subset:

# %%
desired_columns = ['Account Length', 'Phone', 'Eve Charge', 'Night Calls']
subset = data[desired_columns]
subset.head()
# Out:
#    Account Length     Phone  Eve Charge  Night Calls
# 0             128  382-4657       16.78           91
# 1             107  371-7191       16.62          103
# 2             137  358-1921       10.30          104
# 3              84  375-9999        5.26           89
# 4              75  330-6626       12.61          121

# %% [markdown]
# An easier way to get a subset when there are too many subsets (getting the complementary):

# %%
desired_columns = ['Account Length', 'VMail Message', 'Day Calls']
desired_columns
# Out:
# ['Account Length', 'VMail Message', 'Day Calls']

# %%
all_columns_list = data.columns.values.tolist()
all_columns_list
# Out:
# ['State',
#  'Account Length',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'VMail Message',
#  'Day Mins',
#  'Day Calls',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
# A simple trick to get the complementary list of the columns (based on desired columns):
sublist = [x for x in all_columns_list if x not in desired_columns]
sublist
# Out:
# ['State',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'Day Mins',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
subset = data[sublist]
subset.head()
# Out:
#   State  Area Code     Phone Int'l Plan VMail Plan  Day Mins  Day Charge  \
# 0    KS        415  382-4657         no        yes     265.1       45.07
# 1    OH        415  371-7191         no        yes     161.6       27.47
# 2    NJ        415  358-1921         no         no     243.4       41.38
# 3    OH        408  375-9999        yes         no     299.4       50.90
# 4    OK        415  330-6626        yes         no     166.7       28.34
#
#    Eve Mins  Eve Calls  Eve Charge  Night Mins  Night Calls  Night Charge  \
# 0     197.4         99       16.78       244.7           91         11.01
# 1     195.5        103       16.62       254.4          103         11.45
# 2     121.2        110       10.30       162.6          104          7.32
# 3      61.9         88        5.26       196.9           89          8.86
# 4     148.3        122       12.61       186.9          121          8.41
#
#    Intl Mins  Intl Calls  Intl Charge  CustServ Calls  Churn?
# 0       10.0           3         2.70               1  False.
# 1       13.7           3         3.70               1  False.
# 2       12.2           5         3.29               0  False.
# 3        6.6           7         1.78               2  False.
# 4       10.1           3         2.73               3  False.

# %%
# Another trick to get the complementary:
a = set(desired_columns)
b = set(all_columns_list)
sublist = b-a
sublist = list(sublist)
subset = data[sublist]
subset
# Out:
#       Day Mins  Intl Calls  CustServ Calls  Intl Charge  Eve Charge  \
# 0        265.1           3               1         2.70       16.78
# 1        161.6           3               1         3.70       16.62
# 2        243.4           5               0         3.29       10.30
# 3        299.4           7               2         1.78        5.26
# 4        166.7           3               3         2.73       12.61
# ...        ...         ...             ...          ...         ...
# 3328     156.2           6               2         2.67       18.32
# 3329     231.1           4               3         2.59       13.04
# 3330     180.8           6               2         3.81       24.55
# 3331     213.8          10               2         1.35       13.57
# 3332     234.4           4               0         3.70       22.60
#
#       Day Charge  Eve Calls  Eve Mins  Night Calls  Night Charge     Phone  \
# 0          45.07         99     197.4           91         11.01  382-4657
# 1          27.47        103     195.5          103         11.45  371-7191
# 2          41.38        110     121.2          104          7.32  358-1921
# 3          50.90         88      61.9           89          8.86  375-9999
# 4          28.34        122     148.3          121          8.41  330-6626
# ...          ...        ...       ...          ...           ...       ...
# 3328       26.55        126     215.5           83         12.56  414-4276
# 3329       39.29         55     153.4          123          8.61  370-3271
# 3330       30.74         58     288.8           91          8.64  328-8230
# 3331       36.35         84     159.6          137          6.26  364-6381
# 3332       39.85         82     265.9           77         10.86  400-4344
#
#      Int'l Plan  Area Code  Night Mins  Intl Mins  Churn? State VMail Plan
# 0            no        415       244.7       10.0  False.    KS        yes
# 1            no        415       254.4       13.7  False.    OH        yes
# 2            no        415       162.6       12.2  False.    NJ         no
# 3           yes        408       196.9        6.6  False.    OH         no
# 4           yes        415       186.9       10.1  False.    OK         no
# ...         ...        ...         ...        ...     ...   ...        ...
# 3328         no        415       279.1        9.9  False.    AZ        yes
# 3329         no        415       191.3        9.6  False.    WV         no
# 3330         no        510       191.9       14.1  False.    RI         no
# 3331        yes        510       139.2        5.0  False.    CT         no
# 3332         no        415       241.4       13.7  False.    TN        yes
#
# [3333 rows x 18 columns]

# %% [markdown]
# ### Subset with conditions

# %% [markdown]
# First of all, picking up just a part of the dataset (specifying the beggining, the end and the pace):

# %%
subset[5:100:10]
# Out:
#     Day Mins  Intl Calls  CustServ Calls  Intl Charge  Eve Charge  Day Charge  \
# 5      223.4           6               0         1.70       18.75       37.98
# 15     332.9           9               4         1.46       27.01       56.59
# 25     124.3           5               3         4.19       23.55       21.13
# 35     220.0           6               3         3.97       18.47       37.40
# 45     120.9           5               2         2.30       18.11       20.55
# 55     175.5           3               1         2.75       21.19       29.84
# 65     148.1           5               2         1.67       14.41       25.18
# 75     157.1           2               1         1.65       18.98       26.71
# 85     179.3           7               0         2.32       19.20       30.48
# 95     278.4           5               1         2.65        6.89       47.33
#
#     Eve Calls  Eve Mins  Night Calls  Night Charge     Phone Int'l Plan  \
# 5         101     220.6          118          9.18  391-8027        yes
# 15         97     317.8          128          7.23  351-7269         no
# 25        112     277.1          115         11.28  331-3698         no
# 35        102     217.3           71          6.88  362-1407         no
# 45         92     213.0          116          7.34  353-3061         no
# 55         85     249.3           98         12.16  363-5947         no
# 65         88     169.5          102          9.63  352-8305         no
# 75         72     223.3          111          8.16  350-8921         no
# 85         86     225.9           78         14.54  388-6441         no
# 95        113      81.0          137          7.34  366-4467         no
#
#     Area Code  Night Mins  Intl Mins  Churn? State VMail Plan
# 5         510       203.9        6.3  False.    AL         no
# 15        415       160.6        5.4   True.    NY         no
# 25        415       250.7       15.5  False.    NE         no
# 35        415       152.8       14.7  False.    GA        yes
# 45        408       163.1        8.5  False.    OR        yes
# 55        408       270.2       10.2  False.    IN         no
# 65        415       214.1        6.2  False.    WA        yes
# 75        415       181.4        6.1  False.    MN         no
# 85        510       323.0        8.6  False.    VT        yes
# 95        408       163.2        9.8  False.    AK         no

# %% [markdown]
# This might be a little hard, because you have to know exactly the row numbers of all your info.
# To make it easier, it's possible to determine some conditions for the subset:

# %%
# Users with Day Mins > 300:
data1 = data[data["Day Mins"]>300]
data1
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 15      NY             161        415  351-7269         no         no
# 76      DC              82        415  374-5353         no         no
# 156     OH              83        415  370-9116         no         no
# 197     TX             208        510  378-3625         no         no
# 230     MD              93        408  360-3324        yes         no
# 289     OK              89        510  352-6976         no         no
# 365     CO             154        415  343-5709         no         no
# 534     LA              67        510  373-6784         no         no
# 575     SD             114        415  351-7369         no        yes
# 605     MO             112        415  373-2053         no         no
# 688     MN              13        510  338-7120         no        yes
# 732     IN              48        510  342-6696         no         no
# 815     KY              75        415  341-1191         no         no
# 832     SC              87        408  335-1874         no         no
# 901     CT              23        510  370-5527         no         no
# 975     DE             129        510  332-6181         no         no
# 985     NY              64        415  345-9140        yes         no
# 1078    ME              80        408  333-7631         no         no
# 1165    VT              50        415  387-5891        yes        yes
# 1334    KS             126        408  379-8681         no         no
# 1355    TX              50        408  330-6436         no        yes
# 1679    OK              82        510  393-4823         no         no
# 1830    CT              50        408  351-9037         no         no
# 2028    SD              93        510  408-4836         no         no
# 2215    MS              13        415  413-7468         no         no
# 2259    NC             210        415  363-7802         no        yes
# 2267    MS              29        510  401-6982         no         no
# 2376    NV              42        415  352-5466         no         no
# 2412    WI              89        415  373-4264         no         no
# 2478    TN             123        415  415-3016         no        yes
# 2572    MN             152        415  378-9542         no         no
# 2573    WV             124        415  344-1970         no         no
# 2594    OH             115        510  348-1163        yes         no
# 2629    NH             141        415  402-3370         no        yes
# 2660    NJ              88        415  347-8659         no         no
# 2677    IA              44        415  359-7426         no         no
# 2696    MI              74        415  359-6232         no         no
# 2824    OR              81        415  406-4100         no         no
# 2858    AL             141        510  388-8583         no        yes
# 3072    TX              75        415  417-4456         no         no
# 3132    NC             161        415  394-5489         no         no
# 3207    DC              93        408  345-1994         no        yes
# 3322    MD              62        408  409-1856         no         no
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# 15                0     332.9         67       56.59  ...         97
# 76                0     300.3        109       51.05  ...        100
# 156               0     337.4        120       57.36  ...        116
# 197               0     326.5         67       55.51  ...        113
# 230               0     312.0        109       53.04  ...        100
# 289               0     303.9         95       51.66  ...        114
# 365               0     350.8         75       59.64  ...         94
# 534               0     310.4         97       52.77  ...        123
# 575              36     309.9         90       52.68  ...         89
# 605               0     335.5         77       57.04  ...        109
# 688              21     315.6        105       53.65  ...         71
# 732               0     300.4         94       51.07  ...        103
# 815               0     314.6        102       53.48  ...         86
# 832               0     322.5        106       54.83  ...         93
# 901               0     321.6        107       54.67  ...        115
# 975               0     334.3        118       56.83  ...        104
# 985               0     346.8         55       58.96  ...         79
# 1078              0     322.3        113       54.79  ...         95
# 1165             26     307.1         94       52.21  ...         78
# 1334              0     321.3         99       54.62  ...         93
# 1355             31     302.7         93       51.46  ...        119
# 1679              0     329.8         73       56.07  ...        120
# 1830              0     301.7         82       51.29  ...        118
# 2028              0     328.1        106       55.78  ...         89
# 2215              0     303.2        133       51.54  ...         86
# 2259             31     313.8         87       53.35  ...        103
# 2267              0     313.2        103       53.24  ...        151
# 2376              0     303.9        106       51.66  ...         54
# 2412              0     326.3        112       55.47  ...        110
# 2478             34     305.2         80       51.88  ...        109
# 2572              0     317.8         60       54.03  ...        100
# 2573              0     312.0        112       53.04  ...        109
# 2594              0     345.3         81       58.70  ...        106
# 2629             32     322.4         92       54.81  ...        107
# 2660              0     301.5        136       51.26  ...         72
# 2677              0     308.6        139       52.46  ...         94
# 2696              0     314.1         86       53.40  ...         99
# 2824              0     324.7         48       55.20  ...         82
# 2858             28     308.0        123       52.36  ...        128
# 3072              0     305.1        106       51.87  ...        115
# 3132              0     322.3        100       54.79  ...        135
# 3207             22     306.2        123       52.05  ...         83
# 3322              0     321.1        105       54.59  ...        122
#
#       Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  \
# 15         27.01       160.6          128          7.23        5.4
# 76         15.39       270.1           73         12.15       11.7
# 156        19.33       153.9          114          6.93       15.8
# 197        14.99       181.7          102          8.18       10.7
# 230        11.00       217.6           74          9.79       10.5
# 289        22.18       312.1           89         14.04        5.3
# 365        18.40       253.9          100         11.43       10.1
# 534         5.65       246.5           99         11.09        9.2
# 575        17.03       183.5          105          8.26       14.2
# 605        18.06       265.0          132         11.93       12.7
# 688        17.76       260.1          123         11.70       12.1
# 732        11.32       197.4           94          8.88        7.2
# 815        14.43       285.1          100         12.83        5.7
# 832        17.39       186.2          128          8.38        9.4
# 901        21.39       141.1          158          6.35       11.3
# 975        16.33       191.0           83          8.59       10.4
# 985        21.21       275.4          102         12.39       13.3
# 1078       18.87       162.8          123          7.33        6.7
# 1165       24.60       174.9          109          7.87        8.0
# 1334       14.27       193.6          106          8.71        8.0
# 1355       20.44       193.9          103          8.73       13.6
# 1679       17.71       267.1          102         12.02       10.6
# 1830       14.20        72.2           89          3.25       10.5
# 2028       12.89       303.5          114         13.66        8.7
# 2215       14.49       227.6           80         10.24       11.5
# 2259       12.55       192.7           97          8.67       10.1
# 2267       18.39       218.4          106          9.83       12.8
# 2376       19.74       147.1           76          6.62        5.8
# 2412       14.03       162.9           97          7.33        7.5
# 2478       13.30       280.0           81         12.60       13.2
# 2572       13.00       123.4           63          5.55       10.4
# 2573       15.30       168.6           94          7.59       12.8
# 2594       17.29       217.5          107          9.79       11.8
# 2629       24.07       209.5          111          9.43        6.7
# 2660       21.90       132.9          118          5.98       13.4
# 2677       12.82       198.7           66          8.94        7.3
# 2696       18.90       259.0          121         11.66       12.3
# 2824       20.09       187.6           78          8.44       13.1
# 2858       21.06       152.9          103          6.88        7.4
# 3072       15.98       235.4          116         10.59        8.5
# 3132       19.58       241.5          104         10.87        7.8
# 3207       16.12       240.3          107         10.81       11.7
# 3322       22.57       180.5           72          8.12       11.5
#
#       Intl Calls  Intl Charge  CustServ Calls  Churn?
# 15             9         1.46               4   True.
# 76             4         3.16               0   True.
# 156            7         4.27               0   True.
# 197            6         2.89               2   True.
# 230            2         2.84               0   True.
# 289            3         1.43               1   True.
# 365            9         2.73               1   True.
# 534           10         2.48               4  False.
# 575            2         3.83               1  False.
# 605            8         3.43               2   True.
# 688            3         3.27               3  False.
# 732            5         1.94               2  False.
# 815            3         1.54               2   True.
# 832            4         2.54               2   True.
# 901            3         3.05               2   True.
# 975            6         2.81               0   True.
# 985            9         3.59               1   True.
# 1078           8         1.81               0   True.
# 1165           3         2.16               0  False.
# 1334           4         2.16               1   True.
# 1355          14         3.67               3  False.
# 1679           6         2.86               0   True.
# 1830           6         2.84               1  False.
# 2028           3         2.35               1   True.
# 2215           3         3.11               0   True.
# 2259           7         2.73               3  False.
# 2267           4         3.46               2   True.
# 2376           3         1.57               1   True.
# 2412           1         2.03               1   True.
# 2478           7         3.56               1  False.
# 2572           7         2.81               1   True.
# 2573           4         3.46               1   True.
# 2594           8         3.19               1   True.
# 2629           3         1.81               1   True.
# 2660           2         3.62               4   True.
# 2677           3         1.97               4   True.
# 2696           5         3.32               3   True.
# 2824           5         3.54               0   True.
# 2858           3         2.00               1  False.
# 3072           5         2.30               0   True.
# 3132           5         2.11               2   True.
# 3207           2         3.16               0  False.
# 3322           2         3.11               4   True.
#
# [43 rows x 21 columns]

# %%
# Users from New York (State = "NY")
data2 = data[data["State"]=="NY"]
data2
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 15      NY             161        415  351-7269         no         no
# 77      NY             144        408  360-1171         no         no
# 136     NY              75        415  374-8525         no        yes
# 182     NY              67        408  405-2888         no        yes
# 186     NY             106        408  422-1471         no         no
# ...    ...             ...        ...       ...        ...        ...
# 3219    NY             150        415  421-6268         no        yes
# 3227    NY             209        415  369-8703         no         no
# 3257    NY             171        415  412-6245         no         no
# 3275    NY             120        510  405-5083         no        yes
# 3310    NY              94        415  363-1123         no         no
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# 15                0     332.9         67       56.59  ...         97
# 77                0      61.6        117       10.47  ...         85
# 136              21     175.8         97       29.89  ...        106
# 182              36     115.6        111       19.65  ...         94
# 186               0     158.7         74       26.98  ...        139
# ...             ...       ...        ...         ...  ...        ...
# 3219             35     139.6         72       23.73  ...        170
# 3227              0     153.7        105       26.13  ...         87
# 3257              0     137.5        110       23.38  ...        109
# 3275             27     128.5        115       21.85  ...         91
# 3310              0     190.4         91       32.37  ...        107
#
#       Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  \
# 15         27.01       160.6          128          7.23        5.4
# 77          6.55       173.0           99          7.79        8.2
# 136        18.49       237.5          134         10.69        5.3
# 182        20.20       169.9          103          7.65        9.9
# 186         5.47       198.5          103          8.93       10.2
# ...          ...         ...          ...           ...        ...
# 3219       28.29       213.8          105          9.62        8.8
# 3227       16.03       200.8           95          9.04       10.7
# 3257       16.84       292.7          131         13.17       13.3
# 3275       13.91       242.9          121         10.93        0.0
# 3310        7.82       224.8          108         10.12       13.6
#
#       Intl Calls  Intl Charge  CustServ Calls  Churn?
# 15             9         1.46               4   True.
# 77             7         2.21               4   True.
# 136            4         1.43               5  False.
# 182           12         2.67               2  False.
# 186            4         2.75               1  False.
# ...          ...          ...             ...     ...
# 3219           2         2.38               2  False.
# 3227           2         2.89               0  False.
# 3257           5         3.59               2  False.
# 3275           0         0.00               1  False.
# 3310          17         3.67               2  False.
#
# [83 rows x 21 columns]

# %%
# Mixing both of conditions with an and (&)
data3 = data[(data["State"] == "NY") & (data["Day Mins"] > 300)]
data3
# Out:
#     State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 15     NY             161        415  351-7269         no         no
# 985    NY              64        415  345-9140        yes         no
#
#      VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# 15               0     332.9         67       56.59  ...         97
# 985              0     346.8         55       58.96  ...         79
#
#      Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# 15        27.01       160.6          128          7.23        5.4           9
# 985       21.21       275.4          102         12.39       13.3           9
#
#      Intl Charge  CustServ Calls  Churn?
# 15          1.46               4   True.
# 985         3.59               1   True.
#
# [2 rows x 21 columns]

# %%
# Mixing both of conditions with and or (|)
data4 = data[(data["State"] == "NY") | (data["Day Mins"] > 300)]
data4
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 15      NY             161        415  351-7269         no         no
# 76      DC              82        415  374-5353         no         no
# 77      NY             144        408  360-1171         no         no
# 136     NY              75        415  374-8525         no        yes
# 156     OH              83        415  370-9116         no         no
# ...    ...             ...        ...       ...        ...        ...
# 3227    NY             209        415  369-8703         no         no
# 3257    NY             171        415  412-6245         no         no
# 3275    NY             120        510  405-5083         no        yes
# 3310    NY              94        415  363-1123         no         no
# 3322    MD              62        408  409-1856         no         no
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# 15                0     332.9         67       56.59  ...         97
# 76                0     300.3        109       51.05  ...        100
# 77                0      61.6        117       10.47  ...         85
# 136              21     175.8         97       29.89  ...        106
# 156               0     337.4        120       57.36  ...        116
# ...             ...       ...        ...         ...  ...        ...
# 3227              0     153.7        105       26.13  ...         87
# 3257              0     137.5        110       23.38  ...        109
# 3275             27     128.5        115       21.85  ...         91
# 3310              0     190.4         91       32.37  ...        107
# 3322              0     321.1        105       54.59  ...        122
#
#       Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  \
# 15         27.01       160.6          128          7.23        5.4
# 76         15.39       270.1           73         12.15       11.7
# 77          6.55       173.0           99          7.79        8.2
# 136        18.49       237.5          134         10.69        5.3
# 156        19.33       153.9          114          6.93       15.8
# ...          ...         ...          ...           ...        ...
# 3227       16.03       200.8           95          9.04       10.7
# 3257       16.84       292.7          131         13.17       13.3
# 3275       13.91       242.9          121         10.93        0.0
# 3310        7.82       224.8          108         10.12       13.6
# 3322       22.57       180.5           72          8.12       11.5
#
#       Intl Calls  Intl Charge  CustServ Calls  Churn?
# 15             9         1.46               4   True.
# 76             4         3.16               0   True.
# 77             7         2.21               4   True.
# 136            4         1.43               5  False.
# 156            7         4.27               0   True.
# ...          ...          ...             ...     ...
# 3227           2         2.89               0  False.
# 3257           5         3.59               2  False.
# 3275           0         0.00               1  False.
# 3310          17         3.67               2  False.
# 3322           2         3.11               4   True.
#
# [124 rows x 21 columns]

# %% [markdown]
# ### Subsets with loc and iloc

# %%
# Filtering rows and columns:
subset_first_50 = data[["Day Mins", "Night Mins", "Account Length"]][:50]
subset_first_50.shape
# Out:
# (50, 3)

# %%
# An easier way for consulting -> iloc(index of rows, index of columns):
data.iloc[1:10, 3:6] # Consulting first 10 rows of columns between 3 and 6
# Out:
#       Phone Int'l Plan VMail Plan
# 1  371-7191         no        yes
# 2  358-1921         no         no
# 3  375-9999        yes         no
# 4  330-6626        yes         no
# 5  391-8027        yes         no
# 6  355-9993         no        yes
# 7  329-9001        yes         no
# 8  335-4719         no         no
# 9  330-8173        yes        yes

# %%
# An easier way for consulting -> loc(index of rows, label of columns):
data.loc[1:10, ["Phone", "Int'l Plan", "VMail Plan"]] # Consulting first 10 rows of columns labeled as Phone, Int'l Plan and VMail Plan
# Out:
#        Phone Int'l Plan VMail Plan
# 1   371-7191         no        yes
# 2   358-1921         no         no
# 3   375-9999        yes         no
# 4   330-6626        yes         no
# 5   391-8027        yes         no
# 6   355-9993         no        yes
# 7   329-9001        yes         no
# 8   335-4719         no         no
# 9   330-8173        yes        yes
# 10  329-6603         no         no

# %% [markdown]
# ### Inserting columns to the data set

# %%
data["Total Mins"] = data["Day Mins"] + data["Night Mins"] + data["Eve Mins"]
data.loc[:, ["Day Mins", "Night Mins", "Eve Mins", "Total Mins"]]
# Out:
#       Day Mins  Night Mins  Eve Mins  Total Mins
# 0        265.1       244.7     197.4       707.2
# 1        161.6       254.4     195.5       611.5
# 2        243.4       162.6     121.2       527.2
# 3        299.4       196.9      61.9       558.2
# 4        166.7       186.9     148.3       501.9
# ...        ...         ...       ...         ...
# 3328     156.2       279.1     215.5       650.8
# 3329     231.1       191.3     153.4       575.8
# 3330     180.8       191.9     288.8       661.5
# 3331     213.8       139.2     159.6       512.6
# 3332     234.4       241.4     265.9       741.7
#
# [3333 rows x 4 columns]
