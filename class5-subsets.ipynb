# %% [markdown]
# # Extracting a data subset from a data set

# %%
import pandas as pd

# %%
data = pd.read_csv(r'../datasets/customer-churn-model/Customer Churn Model.txt')

# %%
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# 0       244.7           91         11.01       10.0           3         2.70
# 1       254.4          103         11.45       13.7           3         3.70
# 2       162.6          104          7.32       12.2           5         3.29
# 3       196.9           89          8.86        6.6           7         1.78
# 4       186.9          121          8.41       10.1           3         2.73
#
#    CustServ Calls  Churn?
# 0               1  False.
# 1               1  False.
# 2               0  False.
# 3               2  False.
# 4               3  False.
#
# [5 rows x 21 columns]

# %% [markdown]
# Selecting a serie from the dataset (type = Series):

# %%
account_length = data['Account Length']
account_length.head()
# Out:
# 0    128
# 1    107
# 2    137
# 3     84
# 4     75
# Name: Account Length, dtype: int64

# %%
type(account_length)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Selecting multiple series from the dataset (typer = DataFrame):

# %%
subset = data[['Account Length', 'Phone', 'Eve Charge', 'Day Calls']]
subset.head()
# Out:
#    Account Length     Phone  Eve Charge  Day Calls
# 0             128  382-4657       16.78        110
# 1             107  371-7191       16.62        123
# 2             137  358-1921       10.30        114
# 3              84  375-9999        5.26         71
# 4              75  330-6626       12.61        113

# %%
type(subset)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# An easier way to get a subset:

# %%
desired_columns = ['Account Length', 'Phone', 'Eve Charge', 'Night Calls']
subset = data[desired_columns]
subset.head()
# Out:
#    Account Length     Phone  Eve Charge  Night Calls
# 0             128  382-4657       16.78           91
# 1             107  371-7191       16.62          103
# 2             137  358-1921       10.30          104
# 3              84  375-9999        5.26           89
# 4              75  330-6626       12.61          121

# %% [markdown]
# An easier way to get a subset when there are too many subsets (getting the complementary):

# %%
desired_columns = ['Account Length', 'VMail Message', 'Day Calls']
desired_columns
# Out:
# ['Account Length', 'VMail Message', 'Day Calls']

# %%
all_columns_list = data.columns.values.tolist()
all_columns_list
# Out:
# ['State',
#  'Account Length',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'VMail Message',
#  'Day Mins',
#  'Day Calls',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
# A simple trick to get the complementary list of the columns (based on desired columns):
sublist = [x for x in all_columns_list if x not in desired_columns]
sublist
# Out:
# ['State',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'Day Mins',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
subset = data[sublist]
subset.head()
# Out:
#   State  Area Code     Phone Int'l Plan VMail Plan  Day Mins  Day Charge  \
# 0    KS        415  382-4657         no        yes     265.1       45.07
# 1    OH        415  371-7191         no        yes     161.6       27.47
# 2    NJ        415  358-1921         no         no     243.4       41.38
# 3    OH        408  375-9999        yes         no     299.4       50.90
# 4    OK        415  330-6626        yes         no     166.7       28.34
#
#    Eve Mins  Eve Calls  Eve Charge  Night Mins  Night Calls  Night Charge  \
# 0     197.4         99       16.78       244.7           91         11.01
# 1     195.5        103       16.62       254.4          103         11.45
# 2     121.2        110       10.30       162.6          104          7.32
# 3      61.9         88        5.26       196.9           89          8.86
# 4     148.3        122       12.61       186.9          121          8.41
#
#    Intl Mins  Intl Calls  Intl Charge  CustServ Calls  Churn?
# 0       10.0           3         2.70               1  False.
# 1       13.7           3         3.70               1  False.
# 2       12.2           5         3.29               0  False.
# 3        6.6           7         1.78               2  False.
# 4       10.1           3         2.73               3  False.

# %%
# Another trick to get the complementary:
a = set(desired_columns)
b = set(all_columns_list)
sublist = b-a
sublist = list(sublist)
subset = data[sublist]
subset
# Out:
#      VMail Plan  CustServ Calls     Phone  Eve Mins Int'l Plan  Night Charge  \
# 0           yes               1  382-4657     197.4         no         11.01
# 1           yes               1  371-7191     195.5         no         11.45
# 2            no               0  358-1921     121.2         no          7.32
# 3            no               2  375-9999      61.9        yes          8.86
# 4            no               3  330-6626     148.3        yes          8.41
# ...         ...             ...       ...       ...        ...           ...
# 3328        yes               2  414-4276     215.5         no         12.56
# 3329         no               3  370-3271     153.4         no          8.61
# 3330         no               2  328-8230     288.8         no          8.64
# 3331         no               2  364-6381     159.6        yes          6.26
# 3332        yes               0  400-4344     265.9         no         10.86
#
#       Day Mins  Eve Charge  Area Code  Intl Charge State  Churn?  Day Charge  \
# 0        265.1       16.78        415         2.70    KS  False.       45.07
# 1        161.6       16.62        415         3.70    OH  False.       27.47
# 2        243.4       10.30        415         3.29    NJ  False.       41.38
# 3        299.4        5.26        408         1.78    OH  False.       50.90
# 4        166.7       12.61        415         2.73    OK  False.       28.34
# ...        ...         ...        ...          ...   ...     ...         ...
# 3328     156.2       18.32        415         2.67    AZ  False.       26.55
# 3329     231.1       13.04        415         2.59    WV  False.       39.29
# 3330     180.8       24.55        510         3.81    RI  False.       30.74
# 3331     213.8       13.57        510         1.35    CT  False.       36.35
# 3332     234.4       22.60        415         3.70    TN  False.       39.85
#
#       Intl Calls  Night Mins  Intl Mins  Night Calls  Eve Calls
# 0              3       244.7       10.0           91         99
# 1              3       254.4       13.7          103        103
# 2              5       162.6       12.2          104        110
# 3              7       196.9        6.6           89         88
# 4              3       186.9       10.1          121        122
# ...          ...         ...        ...          ...        ...
# 3328           6       279.1        9.9           83        126
# 3329           4       191.3        9.6          123         55
# 3330           6       191.9       14.1           91         58
# 3331          10       139.2        5.0          137         84
# 3332           4       241.4       13.7           77         82
#
# [3333 rows x 18 columns]
